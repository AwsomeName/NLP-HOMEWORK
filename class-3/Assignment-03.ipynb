# %% [markdown]
# ## Assignments for Week-03

# %% [markdown]
# ### 1. Re-code the titanic machine learning
#
# ###### 1. Random Choose Method to get optimal *k* and *b*
# ###### 2.Supervised Direction to get optimal *k* and *b*
# ###### 3.Gradient Descent to get optimal *k* and *b*

# %% [markdown]
# ----------   Please Check the Titanic_ML_ReCode.ipynb  ----------

# %% [markdown]
# ## 2. Answer following questions:
#
#
# ###### 1. Why we need machine learning methods instead of creating a complicated formula?

# %% [markdown]
# Ans:很多模型非常复杂，很难找到准确的拟合公式。而机器学习可以想对快速的拟合。

# %% [markdown]
# ###### 2.  Wha't's the disadvantages of `the 1st Random Choosen` methods in our course?

# %% [markdown]
# Ans:优化效率低（方向不对），收敛慢。

# %% [markdown]
# ###### 3. Is the `2nd method supervised direction` better than 1st one?  What's the disadvantages of `the 2nd supversied directin` method?

# %% [markdown]
# Ans:第二种方法近似于梯度下降，但是在接近最优解的附近会振荡。

# %% [markdown]
# ###### 4. Why do we use `Derivative / Gredient` to fit a target function?

# %% [markdown]
# Ans:一般目标函数都是凸函数，也就是说模型是有最优解的。梯度方向就是向着最优解最快下降的方向。

# %% [markdown]
# ###### 5. In the words 'Gredient Descent', what's the `Gredient` and what's the `Descent`?

# %% [markdown]
# Ans:梯度就是变化率，下降就是方向，沿着梯度下降最快的方向，因为目标函数往往是差值，所以一般是求目标函数的最小值，所以是沿着梯度下降的方向。如果目标函数是最大值，比如某些最大似然函数，LR模型，那么就可以用梯度上升。但是梯度上升的模型只要在目标函数加一个负号，就可以变成梯度下降。所以一般都是用梯度下降。

# %% [markdown]
# ###### 6. What's the advantages of `the 3rd gradient descent method` compared to the previous methods?

# %% [markdown]
# Ans:参数优化更快，更准确，所以收敛更快。

# %% [markdown]
# ###### 7. Using the simple words to describe: What's the machine leanring.

# %% [markdown]
# Ans:根据数据的特征，设计目标函数，得到最佳的拟合效果。

# %% [markdown]
# ## 3. Finish the search problem

# %% [markdown]
# Please using the search policy to implement an agent. This agent receives two input, one is @param start station and the other is @param destination. Your agent should give the optimal route based on Beijing Subway system.

# %% [markdown]
# > Deadline: 2019-April-20
#
# >Submit: Submit the source code and result to github.

# %% [markdown]
# #### Dataflow:

# %% [markdown]
# ##### 1.	Get data from web page.
#
# > a.	Get web page source from: https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81/408485
#
# > b.	You may need @package requests page to get the response via url
#
# > c.	You may need save the page source to file system.
#
# > d.	The target of this step is get station information of all the subway lines;
#
# > e.	You may need install @package beautiful soup  to get the url information, or just use > Regular Expression to get the url.  Our recommendation is that using the Regular Expression and BeautiflSoup both.
#
# > f.	You may need BFS to get all the related page url from one url.
# Question: Why do we use BFS to traverse web page (or someone said, build a web spider)?  Can DFS do this job? which is better?
# > ans. 这关于具体的任务，取决于想要爬取的内容和目标网站的架构。一般情况下都是两者结合的策略。

# %%
url = 'https://baike.baidu.com/item/北京地铁/408485'

# %%
# 不加这个就重定向到北极星去了。
headers = {
    'Accept-Encoding': 'gzip, deflate, sdch',
    'Accept-Language': 'en-US,en;q=0.8',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Cache-Control': 'max-age=0',
    #'Connection': 'keep-alive',
}

# %%
import requests
response = requests.get(url, headers=headers)
html_content = response.text

# %%
import re
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib
from collections import defaultdict

# %%
# 获取北京各条线路的url
url_pattern = re.compile(
    '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81[\d]*[%|\w|\d]+')
#     [\%[\w|\d]*]*')
# https://baike.baidu.com

# %%
stations_pattern = set(url_pattern.findall(html_content))

# %%
stations_pattern
# Out:
# {'/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E4%BA%A6%E5%BA%84%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%85%AB%E9%80%9A%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%A4%A7%E5%85%B4%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%88%BF%E5%B1%B1%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%98%8C%E5%B9%B3%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%9C%BA%E5%9C%BA%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E7%87%95%E6%88%BF%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E8%A5%BF%E9%83%8A%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%811%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8110%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8113%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8114%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8115%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8116%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%812%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%814%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%815%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%816%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%817%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%818%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%819%E5%8F%B7%E7%BA%BF',
#  '/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81S1%E7%BA%BF'}

# %%
stations_url = set('https://baike.baidu.com' + item for item in stations_pattern)

# %%
stations_url
# Out:
# {'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E4%BA%A6%E5%BA%84%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%85%AB%E9%80%9A%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%A4%A7%E5%85%B4%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%88%BF%E5%B1%B1%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%98%8C%E5%B9%B3%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%9C%BA%E5%9C%BA%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E7%87%95%E6%88%BF%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E8%A5%BF%E9%83%8A%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%811%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8110%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8113%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8114%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8115%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8116%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%812%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%814%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%815%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%816%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%817%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%818%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%819%E5%8F%B7%E7%BA%BF',
#  'https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81S1%E7%BA%BF'}

# %%
res = response
new_context = res.content.decode("utf8","ignore").encode("gbk","ignore")
# print(res.content.decode('utf8'))

# %%
# 获取北京各条线路的名字

# %%
mm = re.findall('/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81[\d]*[%|\w|\d]+\">(北京地铁[\u4e00-\u9fa5]{2}线|北京地铁\d+号线)', res.content.decode('utf8'))

# %%
line_names = set(mm)
print(line_names)
# Out:
# {'北京地铁9号线', '北京地铁4号线', '北京地铁7号线', '北京地铁亦庄线', '北京地铁10号线', '北京地铁昌平线', '北京地铁14号线', '北京地铁5号线', '北京地铁1号线', '北京地铁燕房线', '北京地铁16号线', '北京地铁房山线', '北京地铁13号线', '北京地铁2号线', '北京地铁八通线', '北京地铁机场线', '北京地铁8号线', '北京地铁西郊线', '北京地铁大兴线', '北京地铁15号线', '北京地铁6号线'}

# %%
# contexts=[]
stations=[]
# i=1
#get all lines' stations and distence
for url in stations_url:
    print('get_url: ',url)
    tmp_res = requests.get(url, headers=headers)
    tmp_res.content.decode("utf8","ignore").encode("gbk","ignore")
    tmp_context = tmp_res.content.decode('utf8')
#     contexts.append(tmp_context)
#     i += 1
#     if i > 3 :
#         break
    title = re.findall('<title>(北京地铁[\u4e00-\u9fa5]{2}线|北京地铁[\w|\d]+线)_百度百科</title>', tmp_context)
    print(title)
    print('===============================================================================')
    station_table_pattern = "/item/([%|\w|\d]+%E7%AB%99)"
    station_table = re.findall(station_table_pattern, tmp_context)
    station = [urllib.parse.unquote(s) for s in set(station_table)]
    stations.extend(station)

# #     print(set(station_table))
#     print(stations)
#     print(len(stations[0]))
#     break
# Out:
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%819%E5%8F%B7%E7%BA%BF
# ['北京地铁9号线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%85%AB%E9%80%9A%E7%BA%BF
# ['北京地铁八通线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%A4%A7%E5%85%B4%E7%BA%BF
# ['北京地铁大兴线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%9C%BA%E5%9C%BA%E7%BA%BF
# ['北京地铁机场线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%811%E5%8F%B7%E7%BA%BF
# ['北京地铁1号线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%818%E5%8F%B7%E7%BA%BF
# ['北京地铁8号线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%815%E5%8F%B7%E7%BA%BF
# ['北京地铁5号线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%812%E5%8F%B7%E7%BA%BF
# ['北京地铁2号线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E8%A5%BF%E9%83%8A%E7%BA%BF
# []
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E7%87%95%E6%88%BF%E7%BA%BF
# ['北京地铁燕房线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%814%E5%8F%B7%E7%BA%BF
# ['北京地铁4号线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93
'生物医药基地站', '平安里站', '篱笆房站', '珠市口站', '八角游乐园站', '回龙观东大街站', '九龙山站', '化工站', '中关村站', '昌平西山口站', '万安站', '昌平东关站', '海淀黄庄站', '亦庄火车站', '湾子站', '火箭万源站', '人民大学站', '军事博物馆站', '新街口站', '角门西站', '景泰站', '阎村东站', '望京站', '四道桥站', '公益西桥站', '临河里站', '高米店南站', '垡头站', '沙河高教园站', '西直门站', '黄渠站', '小园站', '动物园站', '牛街站', '朱辛庄站', '北工大西门站', '清华东站', '知春里站', '顺义站', '复兴门站', '方庄站', '东风北桥站', '宛平城站', '国展站', '瀛海站', '东夏园站'}

# %%
station_connection = defaultdict(list)
connection_distence = defaultdict()

for url in stations_url:
    print('get_url: ',url)
    tmp_res = requests.get(url, headers=headers)
    tmp_res.content.decode("utf8","ignore").encode("gbk","ignore")
    tmp_context = tmp_res.content.decode('utf8')
#     contexts.append(tmp_context)
#     i += 1
#     if i > 3 :
#         break
    title = re.findall('<title>(北京地铁[\u4e00-\u9fa5]{2}线|北京地铁[\w|\d]+线)_百度百科</title>', tmp_context)
    print(title)
    print('===============================================================================')


    soup = BeautifulSoup(tmp_context, 'lxml')
    tables = soup.select('table')
    df_list = []
    for table in tables:
#     print(type(table.string))[\u4e00-\u9fa5].encode('utf-8','ignore').decode('utf-8','ignore')
        if re.findall("相邻站间距信息统计表", str(table)):
            connections_table = str(table)
#             print(re.findall("[\u4e00-\u9fa5]+——[\u4e00-\u9fa5]+"), connections_table)
#             print(str(table))
#         print("--------------------------------------")
            connections_table = str(table)
            src_stations = re.findall("([\u4e00-\u9fa5]+)——[\u4e00-\u9fa5]+", connections_table)
            dst_stations = re.findall("[\u4e00-\u9fa5]+——([\u4e00-\u9fa5]+)", connections_table)
#         print("--------------------------------------")
            distence = re.findall("(\d+)[\u4e00-\u9fa5]*</td>", connections_table)
            for src, dst, dis in zip(src_stations,dst_stations,distence):
                station_connection[src].append(dst)
                station_connection[dst].append(src)
                com = str(src)+str(dst)
                moc = str(dst)+str(src)
                connection_distence[com] = dis
                connection_distence[moc] = dis
            print(src_stations, '\n', dst_stations, distence)


#     break
# Out:
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%819%E5%8F%B7%E7%BA%BF
# ['北京地铁9号线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%85%AB%E9%80%9A%E7%BA%BF
# ['北京地铁八通线']
# ===============================================================================
# ['四惠', '四惠东', '高碑店', '传媒大学', '双桥', '管庄', '八里桥', '通州北苑', '果园', '九棵树', '梨园', '临河里']
#  ['四惠东', '高碑店', '传媒大学', '双桥', '管庄', '八里桥', '通州北苑', '果园', '九棵树', '梨园', '临河里', '土桥'] ['1715', '1375', '2002', '1894', '1912', '1763', '1700', '1465', '990', '1225', '1257', '776']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%A4%A7%E5%85%B4%E7%BA%BF
# ['北京地铁大兴线']
# ===============================================================================
# ['公益西桥', '新宫', '西红门', '高米店北', '高米店南', '枣园', '清源路', '黄村西大街', '黄村火车站', '义和庄', '生物医药基地']
#  ['新宫', '西红门', '高米店北', '高米店南', '枣园', '清源路', '黄村西大街', '黄村火车站', '义和庄', '生物医药基地', '天宫院'] ['2798', '5102', '1810', '1128', '1096', '1189', '1214', '987', '2035', '2918', '1811']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%9C%BA%E5%9C%BA%E7%BA%BF
# ['北京地铁机场线']
# ===============================================================================
# ['东直门', '航站楼']
#  ['三元桥', '三元桥'] ['3022', '18322', '7243', '20738']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%811%E5%8F%B7%E7%BA%BF
# ['北京地铁1号线']
# ===============================================================================
# ['苹果园', '古城', '八角游乐园', '八宝山', '玉泉路', '五棵松', '万寿路', '公主坟', '军事博物馆', '木樨地', '南礼士路', '复兴门', '西单', '天安门西', '天安门东', '王府井', '东单', '建国门', '永安里', '国贸', '大望路', '四惠']
#  ['古城', '八角游乐园', '八宝山', '玉泉路', '五棵松', '万寿路', '公主坟', '军事博物馆', '木樨地', '南礼士路', '复兴门', '西单', '天安门西', '天安门东', '王府井', '东单', '建国门', '永安里', '国贸', '大望路', '四惠', '四惠东'] ['2606', '1921', '1953', '1479', '1810', '1778', '1313', '1172', '1166', '1291', '424', '1590', '1217', '925', '852', '774', '1230', '1377', '790', '1385', '1673', '1714']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%818%E5%8F%B7%E7%BA%BF
# ['北京地铁8号线']
# ===============================================================================
# ['朱辛庄', '育知路', '平西府', '回龙观东大街', '霍营', '育新', '西小口', '永泰庄', '林萃桥', '森林公园南门', '奥林匹克公园', '奥体中心', '北土城', '安华桥', '安德里北街', '鼓楼大街', '什刹海']
#  ['育知路', '平西府', '回龙观东大街', '霍营', '育新', '西小口', '永泰庄', '林萃桥', '森林公园南门', '奥林匹克公园', '奥体中心', '北土城', '安华桥', '安德里北街', '鼓楼大街', '什刹海', '南锣鼓巷'] ['2318', '1985', '2056', '1114', '1894', '1543', '1041', '2553', '2555', '1016', '1667', '900', '1018', '1274', '1083', '1188', '902']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%815%E5%8F%B7%E7%BA%BF
# ['北京地铁5号线']
# ===============================================================================
# ['天通苑北', '天通苑', '天通苑南', '立水桥', '立水桥南', '北苑路北', '大屯路东', '惠新西街北口', '惠新西街南口', '和平西桥', '和平里北街', '雍和宫', '北新桥', '张自忠路', '东四', '灯市口', '东单', '崇文门', '磁器口', '天坛东门', '蒲黄榆', '刘家窑']
#  ['天通苑', '天通苑南', '立水桥', '立水桥南', '北苑路北', '大屯路东', '惠新西街北口', '惠新西街南口', '和平西桥', '和平里北街', '雍和宫', '北新桥', '张自忠路', '东四', '灯市口', '东单', '崇文门', '磁器口', '天坛东门', '蒲黄榆', '刘家窑', '宋家庄'] ['939', '965', '1544', '1305', '1286', '3', '1838', '1122', '1025', '1059', '1151', '866', '791', '1016', '848', '945', '821', '876', '1183', '9', '905', '1670']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%812%E5%8F%B7%E7%BA%BF
# ['北京地铁2号线']
# ===============================================================================
# ['西直门', '车公庄', '阜成门', '复兴门', '长椿街', '宣武门', '和平门', '前门', '崇文门', '北京站', '建国门', '朝阳门', '东四十条', '东直门', '雍和宫', '安定门', '鼓楼大街', '积水潭']
#  ['车公庄', '阜成门', '复兴门', '长椿街', '宣武门', '和平门', '前门', '崇文门', '北京站', '建国门', '朝阳门', '东四十条', '东直门', '雍和宫', '安定门', '鼓楼大街', '积水潭', '西直门'] ['909', '960', '1832', '1234', '929', '851', '1171', '1634', '1023', '945', '1763', '1027', '824', '2228', '794', '1237', '1766', '1899']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E8%A5%BF%E9%83%8A%E7%BA%BF
# []
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E7%87%95%E6%88%BF%E7%BA%BF
# ['北京地铁燕房线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%814%E5%8F%B7%E7%BA%BF
# ['北京地铁4号线']
# ===============================================================================
# ['安河桥北', '北宫门', '西苑', '圆明园', '北京大学东门', '中关村', '海淀黄庄', '人民大学', '魏公村', '国家图书馆', '动物园', '西直门', '新街口', '平安里', '西四', '灵境胡同', '西单', '宣武门', '菜市口', '陶然亭', '北京南站', '马家堡', '角门西']
#  ['北宫门', '西苑', '圆明园', '北京大学东门', '中关村', '海淀黄庄', '人民大学', '魏公村', '国家图书馆', '动物园', '西直门', '新街口', '平安里', '西四', '灵境胡同', '西单', '宣武门', '菜市口', '陶然亭', '北京南站', '马家堡', '角门西', '公益西桥'] ['1363', '1251', '1672', '1295', '887', '900', '1063', '1051', '1658', '1517', '1441', '1025', '1100', '1100', '869', '1011', '815', '1152', '1200', '1643', '1480', '827', '989']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%88%BF%E5%B1%B1%E7%BA%BF
# ['北京地铁房山线']
# ===============================================================================
# ['郭公庄', '大葆台', '稻田', '长阳', '篱笆房', '广阳城', '良乡大学城北', '良乡大学城', '良乡大学城西', '良乡南关', '苏庄']
#  ['大葆台', '稻田', '长阳', '篱笆房', '广阳城', '良乡大学城北', '良乡大学城', '良乡大学城西', '良乡南关', '苏庄', '阎村东'] ['1405', '6466', '4041', '2150', '1474', '2003', '1188', '1738', '1332', '1330', '2300']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81S1%E7%BA%BF
# ['北京地铁S1线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E4%BA%A6%E5%BA%84%E7%BA%BF
# ['北京地铁亦庄线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8113%E5%8F%B7%E7%BA%BF
# ['北京地铁13号线']
# ===============================================================================
# ['西直门', '大钟寺', '知春路', '五道口', '上地', '西二旗', '龙泽', '回龙观', '霍营', '立水桥', '北苑', '望京西', '芍药居', '光熙门', '柳芳']
#  ['大钟寺', '知春路', '五道口', '上地', '西二旗', '龙泽', '回龙观', '霍营', '立水桥', '北苑', '望京西', '芍药居', '光熙门', '柳芳', '东直门'] ['2839', '1206', '1829', '4866', '2538', '3623', '1423', '2110', '4785', '2272', '6722', '2152', '1110', '1135', '1769']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%817%E5%8F%B7%E7%BA%BF
# ['北京地铁7号线']
# ===============================================================================
# ['北京西站', '湾子', '达官营', '广安门内', '菜市口', '虎坊桥', '珠市口', '桥湾', '磁器口', '广渠门内', '广渠门外', '双井', '九龙山', '大郊亭', '百子湾', '化工', '南楼梓庄', '欢乐谷景区', '垡头', '双合']
#  ['湾子', '达官营', '广安门内', '菜市口', '虎坊桥', '珠市口', '桥湾', '磁器口', '广渠门内', '广渠门外', '双井', '九龙山', '大郊亭', '百子湾', '化工', '南楼梓庄', '欢乐谷景区', '垡头', '双合', '焦化厂'] ['935', '734', '1874', '1374', '885', '1205', '869', '1016', '1138', '1332', '1241', '1311', '781', '865', '903', '1464', '906', '1679', '1304', '1021']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8114%E5%8F%B7%E7%BA%BF
# ['北京地铁14号线']
# ===============================================================================
# ['张郭庄', '园博园', '大瓦窑', '郭庄子', '大井', '七里庄']
#  ['园博园', '大瓦窑', '郭庄子', '大井', '七里庄', '西局'] ['1345', '4073', '1236', '2044', '1579', '845']
# ['北京南站', '陶然桥', '永定门外', '景泰', '蒲黄榆', '方庄', '十里河', '南八里庄', '北工大西门', '平乐园', '九龙山', '大望路', '红庙', '金台路', '朝阳公园', '枣营', '东风北桥', '将台', '高家园', '望京南', '阜通', '望京', '东湖渠', '来广营']
#  ['陶然桥', '永定门外', '景泰', '蒲黄榆', '方庄', '十里河', '南八里庄', '北工大西门', '平乐园', '九龙山', '大望路', '红庙', '金台路', '朝阳公园', '枣营', '东风北桥', '将台', '高家园', '望京南', '阜通', '望京', '东湖渠', '来广营', '善各庄'] ['887', '1063', '1119', '1025', '1486', '1618', '1147', '1276', '1128', '897', '1780', '708', '894', '1085', '1221', '2173', '1600', '1171', '676', '1168', '903', '1283', '1100', '1364']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8116%E5%8F%B7%E7%BA%BF
# ['北京地铁16号线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%98%8C%E5%B9%B3%E7%BA%BF
# ['北京地铁昌平线']
# ===============================================================================
# ['昌平西山口', '十三陵景区', '昌平', '昌平东关', '北邵洼', '南邵', '沙河高教园', '沙河', '巩华城', '朱辛庄', '生命科学园']
#  ['十三陵景区', '昌平', '昌平东关', '北邵洼', '南邵', '沙河高教园', '沙河', '巩华城', '朱辛庄', '生命科学园', '西二旗'] ['1213', '3508', '2433', '1683', '1958', '5357', '1964', '2025', '3799', '2367', '5440']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8110%E5%8F%B7%E7%BA%BF
# ['北京地铁10号线']
# ===============================================================================
# ['巴沟', '苏州街', '海淀黄庄', '知春里', '知春路', '西土城', '牡丹园', '健德门', '北土城', '安贞门', '惠新西街南口', '芍药居', '太阳宫', '三元桥', '亮马桥', '农业展览馆', '团结湖', '呼家楼', '金台夕照', '国贸', '双井', '劲松', '潘家园', '十里河', '分钟寺', '成寿寺', '宋家庄', '石榴庄', '大红门', '角门东', '角门西', '草桥', '纪家庙', '首经贸', '丰台站', '泥洼', '西局', '六里桥', '莲花桥', '公主坟', '西钓鱼台', '慈寿寺', '车道沟', '长春桥', '火器营']
#  ['苏州街', '海淀黄庄', '知春里', '知春路', '西土城', '牡丹园', '健德门', '北土城', '安贞门', '惠新西街南口', '芍药居', '太阳宫', '三元桥', '亮马桥', '农业展览馆', '团结湖', '呼家楼', '金台夕照', '国贸', '双井', '劲松', '潘家园', '十里河', '分钟寺', '成寿寺', '宋家庄', '石榴庄', '大红门', '角门东', '角门西', '草桥', '纪家庙', '首经贸', '丰台站', '泥洼', '西局', '六里桥', '莲花桥', '公主坟', '西钓鱼台', '慈寿寺', '车道沟', '长春桥', '火器营', '巴沟'] ['1110', '950', '975', '1058', '1101', '1330', '973', '1', '1020', '982', '1712', '1003', '1759', '1506', '914', '853', '1149', '734', '835', '1759', '1006', '1021', '1097', '1804', '1058', '1677', '1269', '1244', '1130', '1254', '1688', '1547', '1143', '1717', '954', '749', '1584', '2392', '1016', '2386', '1214', '1590', '1205', '961', '1495']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%8115%E5%8F%B7%E7%BA%BF
# ['北京地铁15号线']
# ===============================================================================
# ['清华东路西口', '六道口', '北沙滩', '奥林匹克公园', '安立路', '大屯路东', '关庄', '望京西', '望京', '望京东', '崔各庄', '马泉营', '孙河', '国展', '花梨坎', '后沙峪', '南法信', '石门', '顺义']
#  ['六道口', '北沙滩', '奥林匹克公园', '安立路', '大屯路东', '关庄', '望京西', '望京', '望京东', '崔各庄', '马泉营', '孙河', '国展', '花梨坎', '后沙峪', '南法信', '石门', '顺义', '俸伯'] ['1144', '1337', '1999', '1368', '938', '1087', '2071', '1758', '1652', '2295', '2008', '3309', '3386', '1615', '3354', '4576', '2712', '1331', '2441']
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%816%E5%8F%B7%E7%BA%BF
# ['北京地铁6号线']
# ===============================================================================
# ['海淀五路居', '慈寿寺', '花园桥', '白石桥南', '车公庄西', '车公庄', '平安里', '北海北', '南锣鼓巷', '东四', '朝阳门', '东大桥', '呼家楼', '金台路', '十里堡', '青年路', '褡裢坡', '黄渠', '常营', '草房', '物资学院路', '通州北关', '通运门', '北运河西', '北运河东', '郝家府', '东夏园']
#  ['慈寿寺', '花园桥', '白石桥南', '车公庄西', '车公庄', '平安里', '北海北', '南锣鼓巷', '东四', '朝阳门', '东大桥', '呼家楼', '金台路', '十里堡', '青年路', '褡裢坡', '黄渠', '常营', '草房', '物资学院路', '通州北关', '通运门', '北运河西', '北运河东', '郝家府', '东夏园', '潞城'] ['1508', '1431', '1166', '1664', '887', '1443', '1321', '1349', '1937', '1399', '1668', '845', '1450', '2036', '1282', '3999', '1238', '1854', '1405', '2115', '2557', '1468', '1543', '1599', '929', '1346', '1194']

# %%
print(station_connection)
# Out:
# defaultdict(<class 'list'>, {'四惠': ['四惠东', '大望路', '四惠东'], '四惠东': ['四惠', '高碑店', '四惠'], '高碑店': ['四惠东', '传媒大学'], '传媒大学': ['高碑店', '双桥'], '双桥': ['传媒大学', '管庄'], '管庄': ['双桥', '八里桥'], '八里桥': ['管庄', '通州北苑'], '通州北苑': ['八里桥', '果园'], '果园': ['通州北苑', '九棵树'], '九棵树': ['果园', '梨园'], '梨园': ['九棵树', '临河里'], '临河里': ['梨园', '土桥'], '土桥': ['临河里'], '公益西
# %%
station_connection['霍营']
# Out:
# ['回龙观东大街', '育新', '回龙观', '立水桥']

# %%
connection_distence['育新霍营']
# Out:
# '1894'

# %% [markdown]
# ##### 2.	Preprocessing data from page source.
#
# > a.	Based on the page source gotten from url. You may need some more preprocessing of the page.
#
# > b.	the Regular Expression you may need to process the text information.
#
# > c.	You may need @package networkx, @package matplotlib to visualize data.
#
# > d.	You should build a dictionary or graph which could represent the connection information of Beijing subway routes.
#
# > e.	You may need the defaultdict, set data structures to implement this procedure.

# %%
#没有获取座标，所以就不放在networkx展示了

# %% [markdown]
# ##### 3. Build the search agent
#
# > a.	Build the search agent based on the graph we build.
#
# > b.	As much as you can to use the already implemented search agent. You just need to define the is_goal, get_successor, strategy three functions.

# %%
print(station_connection)
print(connection_distence)

# %%
# import math
# import networkx as nx

# %%
def get_station_distance(origin, destination):
    tmp = str(origin) + str(destination)
    return connection_distence[tmp]

# %%
get_station_distance("霍营","育新")
# Out:
# '1894'

# %%
def is_goal(desitination):
    def _wrap(current_path):
        return current_path[-1] == desitination
    return _wrap

# %%
def search(graph, start, is_goal, search_strategy):
    pathes = [[start] ]
    seen = set()
    
    while pathes:
        path = pathes.pop(0)
        froniter = path[-1]
        
        if froniter in seen: continue
        
#         print('froniter:', froniter)
        successors = graph[froniter]
#         print('successors:', successors)
        for city in successors: 
            if city in path: continue
            
            new_path = path+[city]
            
            pathes.append(new_path)
        
            if is_goal(new_path): return new_path
#         print('len(pathes)={}'.format(pathes))
        seen.add(froniter)
        pathes = search_strategy(pathes)

# %%
search(station_connection, start='霍营', 
       is_goal=is_goal('北京西站'), search_strategy=lambda n: n)
# Out:
# ['霍营',
#  '回龙观',
#  '龙泽',
#  '西二旗',
#  '上地',
#  '五道口',
#  '知春路',
#  '大钟寺',
#  '西直门',
#  '车公庄',
#  '阜成门',
#  '复兴门',
#  '西单',
#  '宣武门',
#  '菜市口',
#  '广安门内',
#  '达官营',
#  '湾子',
#  '北京西站']

# %% [markdown]
# ##### 4.	Create different policies for transfer system.
#
# > a.	Define different policies for transfer system.
#
# > b.	Such as Shortest Path Priority（路程最短优先）, Minimum Transfer Priority(最少换乘优先), Comprehensive Priority(综合优先)
#
# > c.	Implement Continuous transfer. Based on the Agent you implemented, please add this feature: Besides the @param start and @param destination two stations, add some more stations, we called @param by_way, it means, our path should from the start and end, but also include the  @param by_way stations.
#
# e.g
# ```
# 1. Input:  start=A,  destination=B, by_way=[C]
#     Output: [A, … .., C, …. B]
# 2. Input: start=A, destination=B, by_way=[C, D, E]
#     Output: [A … C … E … D … B]
#     # based on your policy, the E station could be reached firstly.
# ![image.png](attachment:image.png)
# ```

# %%
def sort_path(cmp_func, beam=-1):
    def _sorted(pathes):
        return sorted(pathes, key=cmp_func)[:beam]
    return _sorted

# %%
def get_path_distance(path):
    distance = 0
    
    for i, c in enumerate(path[:-1]):
        distance += int(get_station_distance(c, path[i+1]))
    
    return distance

# %%
def get_total_station(path):
    return len(path)

# %%
def get_comprehensive_path(path):
    return get_path_distance(path)/100 + get_total_station(path)*10
#这里做了一个系数，考虑公里数太大，而站数太少

# %%
def get_as_much_path(path): 
    return -1 * len(path)

# %%
search(station_connection, start='霍营', 
       is_goal=is_goal('北京西站'), search_strategy=sort_path(get_path_distance, beam=100))
# Out:
# ['霍营',
#  '立水桥',
#  '立水桥南',
#  '北苑路北',
#  '大屯路东',
#  '惠新西街北口',
#  '惠新西街南口',
#  '和平西桥',
#  '和平里北街',
#  '雍和宫',
#  '北新桥',
#  '张自忠路',
#  '东四',
#  '灯市口',
#  '东单',
#  '崇文门',
#  '前门',
#  '和平门',
#  '宣武门',
#  '菜市口',
#  '广安门内',
#  '达官营',
#  '湾子',
#  '北京西站']

# %%
search(station_connection, start='霍营', 
       is_goal=is_goal('北京西站'), search_strategy=sort_path(get_total_station, beam=100))
# Out:
# ['霍营',
#  '回龙观',
#  '龙泽',
#  '西二旗',
#  '上地',
#  '五道口',
#  '知春路',
#  '大钟寺',
#  '西直门',
#  '车公庄',
#  '阜成门',
#  '复兴门',
#  '西单',
#  '宣武门',
#  '菜市口',
#  '广安门内',
#  '达官营',
#  '湾子',
#  '北京西站']

# %%
search(station_connection, start='霍营', 
       is_goal=is_goal('北京西站'), search_strategy=sort_path(get_comprehensive_path, beam=100))
# Out:
# ['霍营',
#  '回龙观',
#  '龙泽',
#  '西二旗',
#  '上地',
#  '五道口',
#  '知春路',
#  '大钟寺',
#  '西直门',
#  '车公庄',
#  '阜成门',
#  '复兴门',
#  '长椿街',
#  '宣武门',
#  '菜市口',
#  '广安门内',
#  '达官营',
#  '湾子',
#  '北京西站']

# %%
search(station_connection, start='霍营', 
       is_goal=is_goal('北京西站'), search_strategy=lambda n: n)
# Out:
# ['霍营',
#  '回龙观',
#  '龙泽',
#  '西二旗',
#  '上地',
#  '五道口',
#  '知春路',
#  '大钟寺',
#  '西直门',
#  '车公庄',
#  '阜成门',
#  '复兴门',
#  '西单',
#  '宣武门',
#  '菜市口',
#  '广安门内',
#  '达官营',
#  '湾子',
#  '北京西站']

# %%
search(station_connection, start='西直门', 
       is_goal=is_goal('菜市口'), search_strategy=sort_path(get_comprehensive_path, beam=100))
# Out:
# ['西直门', '车公庄', '阜成门', '复兴门', '长椿街', '宣武门', '菜市口']

# %%
search(station_connection, start='西直门', 
       is_goal=is_goal('菜市口'), search_strategy=sort_path(get_path_distance, beam=100))
# Out:
# ['西直门', '车公庄', '阜成门', '复兴门', '长椿街', '宣武门', '菜市口']

# %%
search(station_connection, start='西直门', 
       is_goal=is_goal('菜市口'), search_strategy=sort_path(get_total_station, beam=100))
# Out:
# ['西直门', '车公庄', '阜成门', '复兴门', '西单', '宣武门', '菜市口']

# %% [markdown]
# ##### 5.	Test your result with commercial applications.
#
# 将你的结果和高德地图或者百度地图进行比较，如果有不同，请分析原因

# %% [markdown]
# 对比了高德地图，从霍营到北京西站，主要是西直门到菜市口这一段不一样。
# 经过逐站检查，发现我的算法路径上是可以走通的，但是换乘较多。
# 所以在算法中，加入换乘的考量因数，应该就可以接近真实的情况。

# %%
connection_line = defaultdict()

for url in stations_url:
    print('get_url: ',url)
    tmp_res = requests.get(url, headers=headers)
    tmp_res.content.decode("utf8","ignore").encode("gbk","ignore")
    tmp_context = tmp_res.content.decode('utf8')

    title = re.findall('<title>(北京地铁[\u4e00-\u9fa5]{2}线|北京地铁[\w|\d]+线)_百度百科</title>', tmp_context)
    print(title)
    print('===============================================================================')


    soup = BeautifulSoup(tmp_context, 'lxml')
    tables = soup.select('table')
    df_list = []
    for table in tables:
        if re.findall("相邻站间距信息统计表", str(table)):
            connections_table = str(table)
            src_stations = re.findall("([\u4e00-\u9fa5]+)——[\u4e00-\u9fa5]+", connections_table)
            dst_stations = re.findall("[\u4e00-\u9fa5]+——([\u4e00-\u9fa5]+)", connections_table)
            print("--------------------------------------")
            
            for src, dst in zip(src_stations,dst_stations):
                com = str(src)+str(dst)
                moc = str(dst)+str(src)
                connection_line[com] = title
                connection_line[moc] = title
# Out:
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%819%E5%8F%B7%E7%BA%BF
# ['北京地铁9号线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%85%AB%E9%80%9A%E7%BA%BF
# ['北京地铁八通线']
# ===============================================================================
# --------------------------------------
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E5%A4%A7%E5%85%B4%E7%BA%BF
# ['北京地铁大兴线']
# ===============================================================================
# --------------------------------------
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%9C%BA%E5%9C%BA%E7%BA%BF
# ['北京地铁机场线']
# ===============================================================================
# --------------------------------------
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%811%E5%8F%B7%E7%BA%BF
# ['北京地铁1号线']
# ===============================================================================
# --------------------------------------
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%818%E5%8F%B7%E7%BA%BF
# ['北京地铁8号线']
# ===============================================================================
# --------------------------------------
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%815%E5%8F%B7%E7%BA%BF
# ['北京地铁5号线']
# ===============================================================================
# --------------------------------------
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%812%E5%8F%B7%E7%BA%BF
# ['北京地铁2号线']
# ===============================================================================
# --------------------------------------
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E8%A5%BF%E9%83%8A%E7%BA%BF
# []
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E7%87%95%E6%88%BF%E7%BA%BF
# ['北京地铁燕房线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%814%E5%8F%B7%E7%BA%BF
# ['北京地铁4号线']
# ===============================================================================
# --------------------------------------
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E6%88%BF%E5%B1%B1%E7%BA%BF
# ['北京地铁房山线']
# ===============================================================================
# --------------------------------------
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81S1%E7%BA%BF
# ['北京地铁S1线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81%E4%BA%A6%E5%BA%84%E7%BA%BF
# ['北京地铁亦庄线']
# ===============================================================================
# get_url:  https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93
['北京地铁8号线'], '奥体中心北土城': ['北京地铁8号线'], '北土城奥体中心': ['北京地铁8号线'], '北土城安华桥': ['北京地铁8号线'], '安华桥北土城': ['北京地铁8号线'], '安华桥安德里北街': ['北京地铁8号线'], '安德里北街安华桥': ['北京地铁8号线'], '安德里北街鼓楼大街': ['北京地铁8号线'], '鼓楼大街安德里北街': ['北京地铁8号线'], '鼓楼大街什刹海': ['北京地铁8号线'], '什刹海鼓楼大街': ['北京地铁8号线'], '什刹海南锣鼓巷': ['北京地铁8号线'], '南锣鼓巷什刹海': ['北京地铁8号线'], '天通苑北天通苑': ['北京地铁5号线'], '天通苑天通苑北': ['北京地铁5号线'], '天通苑天通苑南': ['北京地铁5号线'], '天通苑南天通苑': ['北京地铁5号线'], '天通苑南立水桥': ['北京地铁5号线'], '立水桥天通苑南': ['北京地铁5号线'], '立水桥立水桥南': ['北京地铁5号线'], '立水桥南立水桥': ['北京地铁5号线'], '立水桥南北苑路北': ['北京地铁5号线'], '北苑路北立水桥南': ['北京地铁5号线'], '北苑路北大屯路东': ['北京地铁5号线'], '大屯路东北苑路北': ['北京地铁5号线'], '大屯路东惠新西街北口': ['北京地铁5号线'], '惠新西街北口大屯路东': ['北京地铁5号线'], '惠新西街北口惠新西街南口': ['北京地铁5号线'], '惠新西街南口惠新西街北口': ['北京地铁5号线'], '惠新西街南口和平西桥': ['北京地铁5号线'], '和平西桥惠新西街南口': ['北京地铁5号线'], '和平西桥和平里北街': ['北京地铁5号线'], '和平里北街和平西桥': ['北京地铁5号线'], '和平里北街雍和宫': ['北京地铁5号线'], '雍和宫和平里北街': ['北京地铁5号线'], '雍和宫北新桥': ['北京地铁5号线'], '北新桥雍和宫': ['北京地铁5号线'], '北新桥张自忠路': ['北京地铁5号线'], '张自忠路北新桥': ['北京地铁5号线'], '张自忠路东四': ['北京地铁5号线'], '东四张自忠路': ['北京地铁5号线'], '东四灯市口': ['北京地铁5号线'], '灯市口东四': ['北京地铁5号线'], '灯市口东单': ['北京地铁5号线'], '东单灯市口': ['北京地铁5号线'], '东单崇文门': ['北京地铁5号线'], '崇文门东单': ['北京地铁5号线'], '崇文门磁器口': ['北京地铁5号线'], '磁器口崇文门': ['北京地铁5号线'], '磁器口天坛东门': ['北京地铁5号线'], '天坛东门磁器口': ['北京地铁5号线'], '天坛东门蒲黄榆': ['北京地铁5号线'], '蒲黄榆天坛东门': ['北京地铁5号线'], '蒲黄榆刘家窑': ['北京地铁5号线'], '刘家窑蒲黄榆': [' ...

# %%
def get_total_line(path):
    cnt = 1
#     if len(path) == 2:
#         first = str(path[0])+str(path[1])
#         print(connection_line[first])
    
    for i, c in enumerate(path[:-2]):
        first = str(c)+str(path[i+1])
        second = str(path[i+1]) + str(path[i+2])
#         print(connection_line[first])
        if connection_line[first] != connection_line[second] :
#             print(connection_line[first])
#             print(connection_line[second])
            cnt += 1
    return cnt

# %%
search(station_connection, start='西直门', 
       is_goal=is_goal('菜市口'), search_strategy=lambda n:n)
# Out:
# ['西直门', '车公庄', '阜成门', '复兴门', '西单', '宣武门', '菜市口']

# %%
search(station_connection, start='西直门', 
       is_goal=is_goal('菜市口'), search_strategy=sort_path(get_total_line, beam=100))
# Out:
# ['西直门', '车公庄', '阜成门', '复兴门', '长椿街', '宣武门', '菜市口']

# %%
search(station_connection, start='西直门', 
       is_goal=is_goal('菜市口'), search_strategy=sort_path(get_comprehensive_path, beam=100))
# Out:
# ['西直门', '车公庄', '阜成门', '复兴门', '长椿街', '宣武门', '菜市口']

# %%
station_connection['西直门']
# Out:
# ['车公庄', '积水潭', '动物园', '新街口', '大钟寺']

# %%
connection_line['西直门大钟寺']
# Out:
# ['北京地铁13号线']

# %% [markdown]
# 发现两个问题，一个是宣武门到菜市口，高德地图中是不支持2号线到4号线直接换乘的。

# %% [markdown]
# 另一个是我们的寻找程序，是有问题的。它设置了标志位SEEN，但是这个标志位比较简单，当很多站有交叉的情况，就会导致一些路径不能遍历。比如西直门到平安里，可以4号线直达，但是这里先检查了2号线，2号线可以在车公庄换乘6号线到达平安里，这样平安里就被标记了，当检查4号线时，整个4号线的路径都被抛弃了。

# %% [markdown]
# 仔细检查，发现问题挺多的。这里应该用广度优先搜索比较合适。所以重写了寻路算法

# %%
def search_N(graph, start, is_goal, search_strategy):
    pathes = [[start]]
    ans = []
    while pathes :
        new_pathes = []
        for path in pathes:
            if len(path) > 30: continue
                
            laster = path[-1]
            nexts = graph[laster]
            for n in nexts:
                if n in path: continue
                
                new_path = path + [n]
                if is_goal(new_path):
                    ans.append(new_path)
#                     print('+++++++++++++++++++++++++++')
#                     print(new_path)
                    
                new_pathes.append(new_path)
                
        pathes = search_strategy(new_pathes)
#         print('len(pathes)={}'.format(len(pathes)), pathes)
    ans = search_strategy(ans)
    return ans[0]

# %%
search_N(station_connection, start='西直门', 
       is_goal=is_goal('菜市口'), search_strategy=sort_path(get_total_line, beam=100))
# Out:
# ['北京地铁2号线']
# ['北京地铁2号线']
# ['北京地铁4号线']
# ['北京地铁4号线']
# ['北京地铁13号线']
# ['西直门', '新街口', '平安里', '西四', '灵境胡同', '西单', '宣武门', '菜市口']

# %%
station_connection['平安里']
# Out:
# ['新街口', '西四', '车公庄', '北海北']

# %%
search_N(station_connection, start='霍营', 
       is_goal=is_goal('北京西站'), search_strategy=sort_path(get_total_line, beam=100))
# Out:
# ['霍营',
#  '回龙观',
#  '龙泽',
#  '西二旗',
#  '上地',
#  '五道口',
#  '知春路',
#  '大钟寺',
#  '西直门',
#  '新街口',
#  '平安里',
#  '西四',
#  '灵境胡同',
#  '西单',
#  '宣武门',
#  '菜市口',
#  '广安门内',
#  '达官营',
#  '湾子',
#  '北京西站']

# %% [markdown]
# 这样的结果，在高德地图中选择地铁优先，就是步行最少的方案。

# %% [markdown]
# 实际上，如果只看地铁图导航，我也会选择这种方案。但是高德的默认结果中并没有。

# %% [markdown]
# 因为高德是根据时间来具体估算的，包括每站之间的时间和换乘的时间。所以这里无法得到和地图一样的时间优先结果。但是如果要考虑做的话也是差不多的流程

# %%
def get_comprehensive_path_N(path):
    return get_path_distance(path)/100 + get_total_station(path)*10 + get_total_line(path)*100

# %%
search_N(station_connection, start='霍营', 
       is_goal=is_goal('北京西站'), search_strategy=sort_path(get_comprehensive_path_N, beam=1000))
# Out:
# ['霍营',
#  '回龙观',
#  '龙泽',
#  '西二旗',
#  '上地',
#  '五道口',
#  '知春路',
#  '大钟寺',
#  '西直门',
#  '新街口',
#  '平安里',
#  '西四',
#  '灵境胡同',
#  '西单',
#  '宣武门',
#  '菜市口',
#  '广安门内',
#  '达官营',
#  '湾子',
#  '北京西站']

# %%
station_connection['北京西站']
# Out:
# ['湾子']

# %%
station_connection['军事博物馆']
# Out:
# ['公主坟', '木樨地']

# %% [markdown]
# 另外又检查了一下，发现是百度百科里的地铁9号线数据不全，没有站点距离表，所以整个算法缺少9号线的数据，而刚好我的实验站点北京西站就是9号线终点站

# %%
search_N(station_connection, start='霍营', 
       is_goal=is_goal('北京南站'), search_strategy=sort_path(get_comprehensive_path_N, beam=1000))
# Out:
# ['霍营',
#  '回龙观',
#  '龙泽',
#  '西二旗',
#  '上地',
#  '五道口',
#  '知春路',
#  '大钟寺',
#  '西直门',
#  '新街口',
#  '平安里',
#  '西四',
#  '灵境胡同',
#  '西单',
#  '宣武门',
#  '菜市口',
#  '陶然亭',
#  '北京南站']

# %% [markdown]
# 这就和高德地图完全一样了。

# %%
def search_ND(graph, start, is_goal, search_strategy):
    pathes = [[start]]
    ans = []
    while pathes :
        new_pathes = []
        for path in pathes:
            if len(path) > 30: continue
                
            laster = path[-1]
            nexts = graph[laster]
            for n in nexts:
                if n in path: continue
                
                new_path = path + [n]
                if is_goal(new_path):
                    ans.append(new_path)
#                     print('+++++++++++++++++++++++++++')
#                     print(new_path)
                    
                new_pathes.append(new_path)
                
        pathes = search_strategy(new_pathes)
#         print('len(pathes)={}'.format(len(pathes)), pathes)
    ans = search_strategy(ans)
    if len(ans) < 10 :
        return ans
    
    return ans[0:10]

# %%
search_ND(station_connection, start='霍营', 
       is_goal=is_goal('四惠东'), search_strategy=sort_path(get_comprehensive_path_N, beam=1000))
# Out:
# [['霍营',
#   '立水桥',
#   '北苑',
#   '望京西',
#   '芍药居',
#   '太阳宫',
#   '三元桥',
#   '亮马桥',
#   '农业展览馆',
#   '团结湖',
#   '呼家楼',
#   '金台夕照',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  ['霍营',
#   '立水桥',
#   '北苑',
#   '望京西',
#   '芍药居',
#   '太阳宫',
#   '三元桥',
#   '亮马桥',
#   '农业展览馆',
#   '团结湖',
#   '呼家楼',
#   '金台夕照',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  ['霍营',
#   '立水桥',
#   '北苑',
#   '望京西',
#   '芍药居',
#   '光熙门',
#   '柳芳',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  ['霍营',
#   '立水桥',
#   '北苑',
#   '望京西',
#   '芍药居',
#   '光熙门',
#   '柳芳',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  ['霍营',
#   '立水桥',
#   '立水桥南',
#   '北苑路北',
#   '大屯路东',
#   '惠新西街北口',
#   '惠新西街南口',
#   '和平西桥',
#   '和平里北街',
#   '雍和宫',
#   '北新桥',
#   '张自忠路',
#   '东四',
#   '灯市口',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  ['霍营',
#   '立水桥',
#   '立水桥南',
#   '北苑路北',
#   '大屯路东',
#   '惠新西街北口',
#   '惠新西街南口',
#   '和平西桥',
#   '和平里北街',
#   '雍和宫',
#   '北新桥',
#   '张自忠路',
#   '东四',
#   '灯市口',
#   '东单',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  ['霍营',
#   '育新',
#   '西小口',
#   '永泰庄',
#   '林萃桥',
#   '森林公园南门',
#   '奥林匹克公园',
#   '奥体中心',
#   '北土城',
#   '安贞门',
#   '惠新西街南口',
#   '芍药居',
#   '太阳宫',
#   '三元桥',
#   '亮马桥',
#   '农业展览馆',
#   '团结湖',
#   '呼家楼',
#   '金台夕照',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  ['霍营',
#   '育新',
#   '西小口',
#   '永泰庄',
#   '林萃桥',
#   '森林公园南门',
#   '奥林匹克公园',
#   '奥体中心',
#   '北土城',
#   '安贞门',
#   '惠新西街南口',
#   '芍药居',
#   '太阳宫',
#   '三元桥',
#   '亮马桥',
#   '农业展览馆',
#   '团结湖',
#   '呼家楼',
#   '金台夕照',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  ['霍营',
#   '育新',
#   '西小口',
#   '永泰庄',
#   '林萃桥',
#   '森林公园南门',
#   '奥林匹克公园',
#   '奥体中心',
#   '北土城',
#   '安华桥',
#   '安德里北街',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东'],
#  ['霍营',
#   '育新',
#   '西小口',
#   '永泰庄',
#   '林萃桥',
#   '森林公园南门',
#   '奥林匹克公园',
#   '奥体中心',
#   '北土城',
#   '安华桥',
#   '安德里北街',
#   '鼓楼大街',
#   '安定门',
#   '雍和宫',
#   '东直门',
#   '东四十条',
#   '朝阳门',
#   '建国门',
#   '永安里',
#   '国贸',
#   '大望路',
#   '四惠',
#   '四惠东']]

# %% [markdown]
# 第一条（第二条和第一条相同，应该是有换乘）是高德第二条，第三条是高德第一条，第八条是高德第三条

# %% [markdown]
# 这里高德地图推荐的3条都能找到。地铁线路毕竟比较简单，相对其他导航。
